# %% [markdown]
# # Classe

# %%
class Human:

    def __init__(self, firstname, lastname, dateofbirth, gender, phone, email):
        if firstname == "Yann" and lastname == "KER*":
            gender = "Breton"
        self.firstname = firstname
        self.lastname = lastname
        self.dateofbirth = dateofbirth
        self.gender = gender
        self.phone = phone
        self.email = email
        self.clothes = []

    def get_infos(self):
        print("Informations :")
        print("Last name : " + self.lastname + "\nFirst name : " + self.firstname + "\nDate of birth : " + self.dateofbirth + "\nGender : " + self.gender + "\nPhone : " + self.phone + "\nEmail : " + self.email)

    def trace(func):
        def decorateur():
            print("Début d'appel à", func)
            func()
            print("Fin d'appel à", func)
        return decorateur

    def add_clothes(self, item):
        self.clothes.append(item)

    def get_clothes(self):
        print("\n" + self.firstname + " " + self.lastname + " dress :")
        for item in self.clothes:
            print("- " + item + "\n")

if __name__ == "__main__":
    h1 = Human("Yann","KERDONCUFF","14/04/2000","Male","0000","yann@kerdoncuff.pro")
    h1.add_clothes("Jacket")
    h1.get_infos()
    h1.get_clothes()

    h2 = Human("Valentin","GAUTREAU","20/02/2001","Male","0000","valentin.gautreau@etu.univ-nantes.fr")
    h2.add_clothes("T-shirt")
    h2.get_infos()
    h2.get_clothes()
    
    h3= Human("Antoine","RAFFRAY","17/06/2001","Male","0000","antoine.raffray@etu.univ-nantes.fr")
    h3.add_clothes("Jean")
    h3.get_infos()
    h3.get_clothes()
# Out:
# Informations :
# Last name : KERDONCUFF
# First name : Yann
# Date of birth : 14/04/2000
# Gender : Male
# Phone : 0000
# Email : yann@kerdoncuff.pro
#
# Yann KERDONCUFF dress :
# - Jacket
#
# Informations :
# Last name : GAUTREAU
# First name : Valentin
# Date of birth : 20/02/2001
# Gender : Male
# Phone : 0000
# Email : valentin.gautreau@etu.univ-nantes.fr
#
# Valentin GAUTREAU dress :
# - T-shirt
#
# Informations :
# Last name : RAFFRAY
# First name : Antoine
# Date of birth : 17/06/2001
# Gender : Male
# Phone : 0000
# Email : antoine.raffray@etu.univ-nantes.fr
#
# Antoine RAFFRAY dress :
# - Jean

# %%
class Animal:
    
    def __init__(self, couleur, poids):
        self.couleur = couleur
        self.poids = poids

    def __str__(self):
        return("\nInformations animal :\nCouleur : " + self.couleur + "\nPoids : " + str(self.poids))
        
    def crier(self):
        return("SUUUUUUUUUUU")
        
class Chien(Animal):
    
    def __init__(self, couleur, poids=30, duree=15):
        super().__init__(couleur, poids)
        self.duree = duree
    
    def afficheDureeVie(self):
        return("\nDurée de vie de l'animal : " + str(self.duree))
    
    def crier(self):
        return("Waf waf waf")
        
if __name__ == "__main__":
    medor = Chien("noir",20,15)
    print(str(medor))
    print(medor.afficheDureeVie())
# Out:
# Informations animal :
# Couleur : noir
# Poids : 20
#
# Durée de vie de l'animal : 15

# %%
class Article:
    
    def __init__(self, prixHT):
        self.prixHT = prixHT

    def __str__(self):
        return("\nInformations animal :\nCouleur : " + self.couleur + "\nPoids : " + str(self.poids))
        
    def crier(self):
        return("SUUUUUUUUUUU")
